# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 23)
pd.set_option('display.max_rows', 300)
songs = pd.read_csv('spotify_songs.csv')
all_songs = pd.read_csv('spotify_songs.csv')

# %%
# Eliminating duplicates
top_songs = pd.DataFrame(songs.groupby('track_name')['track_artist'].value_counts())
top_songs.sort_values(by = ['count'], ascending = False, inplace = True)
filter = top_songs['count'] >= 0
top_tunes = pd.DataFrame(top_songs[filter])
full_data = songs.set_index(['track_name', 'track_artist'], drop = False)
full = full_data.loc[top_tunes.index]
full.sort_values(by = 'track_popularity', ascending = False, inplace = True)
full.drop_duplicates(inplace = True, subset = ['track_name', 'track_artist'])
full.drop(axis = 1, columns = ['track_id', 'playlist_id', 'playlist_id', 'track_id', 'track_album_id', 'mode', 'duration_ms', 'key', 'instrumentalness', 'loudness', 'track_album_name', 'track_album_release_date', 'playlist_name'], inplace = True)
full.index = [x for x in range(0, len(full.index))]
full['corr_score'] = [0.0 for x in range(0, len(full.index))]

# %%
top_songs = pd.DataFrame(songs.groupby('track_name')['track_artist'].value_counts())
# This groups all duplicate songs (same artist and song name, and finds their value_count)
top_songs.sort_values(by = ['count'], ascending = False, inplace = True)
filter = top_songs['count'] >= 0
top_tunes = pd.DataFrame(top_songs[filter])
# the filtering aims to find the most common songs
full_data = songs.set_index(['track_name', 'track_artist'], drop = False)
# An index matching filtering is to happen with the 'track_name' and 'track_artist', which is also the index of our `top_tunes`
full = full_data.loc[top_tunes.index]
# This gets every song in top_tunes with their full data (they only had value counts before
full.sort_values(by = 'track_popularity', ascending = False, inplace = True)
full.drop_duplicates(inplace = True, subset = ['track_name', 'track_artist'])
full.drop(axis = 1, columns = ['track_id', 'playlist_id', 'playlist_id', 'track_id', 'track_album_id', 'mode', 'duration_ms', 'key', 'instrumentalness', 'loudness', 'track_album_name', 'track_album_release_date', 'playlist_name'], inplace = True)
# The df is sorted by highest popularity, and other duplicates are dropped. Columns not needed are dropped too.
full.index = [x for x in range(0, len(full.index))]
full['corr_score'] = [0 for x in range(0, len(full.index))]
# The index is updated. And a new column is added
# Out:
#                                                                                    track_id  \
# track_name                                         track_artist
# I Don't Care (with Justin Bieber) - Loud Luxury... Ed Sheeran        6f807x0ima9a1j3VPbc7VN
# Memories - Dillon Francis Remix                    Maroon 5          0r7CVbZTWZgbTCYdfa2P31
# All the Time - Don Diablo Remix                    Zara Larsson      1z1Hg7Vb0AhHDiEmnDE79l
# Call You Mine - Keanu Silva Remix                  The Chainsmokers  75FpbthrwQmzHlBJLuGdC7
# Someone You Loved - Future Humans Remix            Lewis Capaldi     1e8PAfcKUYoKkxPhrHqw4x
# ...                                                                                     ...
# City Of Lights - Official Radio Edit               Lush & Simon      7bxnKAamR3snQ1VGLuVfC1
# Closer - Sultan & Ned Shepard Remix                Tegan and Sara    5Aevni09Em4575077nkWHz
# Sweet Surrender - Radio Edit                       Starkillers       7ImMqPP3Q1yfUHvsdn7wEo
# Only For You - Maor Levi Remix                     Mat Zo            2m69mhnfQ1Oq6lGtXuYhgX
# Typhoon - Original Mix                             Julian Calor      29zWqhca3zt5NsckZqDf6c
#
#                                                                                                             track_name  \
# track_name                                         track_artist
# I Don't Care (with Justin Bieber) - Loud Luxury... Ed Shee
# Closer - Sultan & Ned Shepard Remix                Tegan and Sara     0.4000
# Sweet Surrender - Radio Edit                       Starkillers        0.4360
# Only For You - Maor Levi Remix                     Mat Zo             0.3080
# Typhoon - Original Mix                             Julian Calor       0.0894
#
#                                                                        tempo  \
# track_name                                         track_artist
# I Don't Care (with Justin Bieber) - Loud Luxury... Ed Sheeran        122.036
# Memories - Dillon Francis Remix                    Maroon 5           99.972
# All the Time - Don Diablo Remix                    Zara Larsson      124.008
# Call You Mine - Keanu Silva Remix                  The Chainsmokers  121.956
# Someone You Loved - Future Humans Remix            Lewis Capaldi     123.976
# ...                                                                      ...
# City Of Lights - Official Radio Edit               Lush & Simon      128.170
# Closer - Sultan & Ned Shepard Remix                Tegan and Sara    128.041
# Sweet Surrender - Radio Edit                       Starkillers       127.989
# Only For You - Maor Levi Remix                     Mat Zo            128.008
# Typhoon - Original Mix                             Julian Calor      127.984
#
#                                                                      duration_ms
# track_name                                         track_artist
# I Don't Care (with Justin Bieber) - Loud Luxury... Ed Sheeran             194754
# Memories - Dillon Francis Remix                    Maroon 5               162600
# All the Time - Don Diablo Remix                    Zara Larsson           176616
# Call You Mine - Keanu Silva Remix                  The Chainsmokers       169093
# Someone You Loved - Future Humans Remix            Lewis Capaldi          189052
# ...                                                                          ...
# City Of Lights - Official Radio Edit               Lush & Simon           204375
# Closer - Sultan & Ned Shepard Remix                Tegan and Sara         353120
# Sweet Surrender - Radio Edit                       Starkillers            210112
# Only For You - Maor Levi Remix                     Mat Zo                 367432
# Typhoon - Original Mix                             Julian Calor           337500
#
# [32833 rows x 23 columns]

# %%
# finding songs similar to my most played songs : The values will be correlated to all other values of other songs, the song that has the 
# highest sum will be the most similar to the song
filtt = full['track_artist'] == 'BTS'
full[filtt]

# I'm just checking for the song to pick here
# Out:
#                                               track_name track_artist  \
# 164                          Boy With Luv (feat. Halsey)          BTS
# 219                           Make It Right (feat. Lauv)          BTS
# 1272                                                IDOL          BTS
# 1978                                           Jamais Vu          BTS
# 2174                                                 DNA          BTS
# 3481   All Night (BTS World Original Soundtrack) [Pt. 3]          BTS
# 3518              Make It Right (feat. Lauv) [EDM Remix]          BTS
# 3970       MIC Drop (feat. Desiigner) [Steve Aoki Remix]          BTS
# 23105                                  21st Century Girl          BTS
# 24153                                           I NEED U          BTS
# 24741                                         불타오르네 FIRE          BTS
#
#        track_popularity playlist_genre   playlist_subgenre  danceability  \
# 164                  85            pop     indie poptimism         0.645
# 219                  83            pop       post-teen pop         0.584
# 1272                 75            pop           dance pop         0.734
# 1978                 71            edm             pop edm         0.608
# 2174                 71            pop           dance pop         0.598
# 3481                 67            r&b  urban contemporary         0.725
# 3518                 66            edm            big room         0.648
# 3970                 65            pop           dance pop         0.613
# 23105                 3            edm             pop edm         0.716
# 24153                 0            edm             pop edm         0.486
# 24741                 0            edm             pop edm         0.428
#
#        energy  speechiness  acousticness  liveness  valence    tempo  \
# 164     0.862       0.0965       0.09230    0.1920    0.798  119.991
# 219     0.685       0.4250       0.03040    0.1890    0.345   97.551
# 1272    0.855       0.1180       0.00481    0.1230    0.422  126.035
# 1978    0.470       0.0428       0.22600    0.0963    0.241   81.000
# 2174    0.775       0.0545       0.02200    0.0677    0.687  129.819
# 3481    0.706       0.1210       0.19300    0.1090    0.667  120.042
# 3518    0.741       0.3130       0.00351    0.0932    0.238  106.001
# 3970    0.842       0.2190       0.01570    0.2300    0.645  169.917
# 23105   0.887       0.0853       0.00402    0.0566    0.782  101.025
# 24153   0.880       0.0706       0.02150    0.2400    0.710  158.043
# 24741   0.708       0.1680       0.00262    0.1210    0.552  199.827
#
#        corr_score
# 164             0
# 219             0
# 1272            0
# 1978            0
# 2174            0
# 3481            0
# 3518            0
# 3970            0
# 23105           0
# 24153           0
# 24741           0

# %%
my_song = (full['track_name'] == 'Jamais Vu') & (full['track_artist'] == 'BTS')
full[my_song]
# Out:
#      track_name track_artist  track_popularity playlist_genre  \
# 1978  Jamais Vu          BTS                71            edm
#
#      playlist_subgenre  danceability  energy  speechiness  acousticness  \
# 1978           pop edm         0.608    0.47       0.0428         0.226
#
#       liveness  valence  tempo  corr_score
# 1978    0.0963    0.241   81.0           0

# %%
full.loc[2, 'energy']
# Out:
# 0.796

# %%
for ind in range(0, len(full.index)):
# The 'ind' correlates to the index
    score_list = []
    song_ind = 26000
# This is the song to be compared
    score_list.append(temp_corr(song_ind, ind))
    score_list.append(energy_corr(song_ind, ind))
    score_list.append(dance_corr(song_ind, ind))
    score_list.append(val_corr(song_ind, ind))
    score_list.append(liv_corr(song_ind, ind))
    score_list.append(speech_corr(song_ind, ind))
    score_list.append(acoust_corr(song_ind, ind))
# The `c` from each of the functions is returned, and it is appended into a list
    total = sum(score_list)
    full.loc[ind, 'corr_score'] = total
# The sum of the list is gotten and its is appended, at a corresponding index in `corr_score` column.

# %%
#corr_terms = ['tempo', 'energy', 'danceability', 'valence', 'liveness', 'speechiness', 'acousticness']
#corr_dict = {x:y for x,y in enumerate(corr_terms)}

for ind in range(0, len(full.index)):
    score_list = []
    song_ind = 29
    score_list.append(temp_corr(song_ind, ind))
    score_list.append(energy_corr(song_ind, ind))
    score_list.append(dance_corr(song_ind, ind))
    score_list.append(val_corr(song_ind, ind))
    score_list.append(liv_corr(song_ind, ind))
    score_list.append(speech_corr(song_ind, ind))
    score_list.append(acoust_corr(song_ind, ind))
    total = sum(score_list)
    full.loc[ind, 'corr_score'] = total
# Out:
# C:\Users\AY\AppData\Local\Temp\ipykernel_2280\4005662268.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '24.55' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   full.loc[ind, 'corr_score'] = total

# %%
full.sort_values(by = 'corr_score', ascending = False).head(20)

#full.head(10)
#filt = full['track_artist'].str.contains('Drake')
#full[filt]
# Out:
#                                               track_name    track_artist  \
# 29     South of the Border (feat. Camila Cabello & Ca...      Ed Sheeran
# 11365                                     Shopping Spree          Equalz
# 6117                                             Nosequé        DJ Valdi
# 6058                                             Speling        DJ DYLVN
# 8934                                              Golden      Jill Scott
# 25197                           Cojela Que Va Sin Jockey    Daddy Yankee
# 3609                                      Así Es la Vida        Elefante
# 1555                                    Síguelo Bailando           Ozuna
# 319                                                  FML  Arizona Zervas
# 4867                                         Bikini Porn         Tove Lo
# 3649                     Pookie (feat. Lil Pump) - Remix    Aya Nakamura
# 31                                          Ayy Macarena            Tyga
# 8721   Good to Be Home (feat. Tom Misch, Loyle Carner...   Barney Artist
# 2189                                             Amantes         Greeicy
# 1354                    Tuesday (feat. Danelle Sandoval)     Burak Yeter
# 10238                                       Just in Case          Jaheim
# 181    fuck, i'm lonely (with Anne-Marie) - from “13 ...            Lauv
# 22355                                        Monkey Move    Nixon Joseph
# 4616                                      Illegal Weapon    Garry Sandhu
# 1254                                           Ya No Mas     Fer Palacio
#
#        track_popularity playlist_genre   playlist_subgenre  danceability  \
# 29                   91            edm             pop edm         0.857
# 11365                47          latin       latin hip hop         0.823
# 6117                 59          latin           reggaeton         0.882
# 6058                 60          latin       latin hip hop         0.868
# 8934                 53            r&b            neo soul         0.769
# 25197                 0          latin           reggaeton         0.825
# 3609                 66          latin           latin pop         0.804
# 1555                 73          latin           reggaeton         0.855
# 319                  82            r&b  urban contemporary         0.822
# 4867                 63            pop     indie poptimism         0.919
# 3649                 66          latin       latin hip hop         0.889
# 31                   91            pop     indie poptimism         0.816
# 8721                 53            r&b            neo soul         0.892
# 2189                 71          latin           latin pop         0.800
# 1354                 74            pop          electropop         0.841
# 10238                50            r&b            neo soul         0.780
# 181                  84            pop       post-teen pop         0.806
# 22355                 8          latin       latin hip hop         0.846
# 4616                 63            rap             hip hop         0.814
# 1254                 75          latin           reggaeton         0.795
#
#        energy  speechiness  acousticness  liveness  valence    tempo  \
# 29      0.621       0.0824        0.1480    0.0865    0.668   97.986
# 11365   0.648       0.0845        0.0763    0.0902    0.623  101.906
# 6117    0.633       0.0852        0.1100    0.0546    0.701   98.024
# 6058    0.568       0.0822        0.0267    0.0741    0.682   97.931
# 8934    0.558       0.0828        0.2750    0.0758    0.593  100.007
# 25197   0.598       0.0949        0.1310    0.1070    0.602   95.029
# 3609    0.670       0.0897        0.1310    0.1480    0.644   97.969
# 1555    0.664       0.0607        0.1650    0.0937    0.626   98.015
# 319     0.575       0.0934        0.1130    0.1060    0.616  100.087
# 4867    0.687       0.0774        0.0839    0.0520    0.675  100.997
# 3649    0.646       0.0740        0.0412    0.0798    0.584   98.005
# 31      0.630       0.2260        0.1330    0.0692    0.715   96.493
# 8721    0.685       0.0720        0.3010    0.0775    0.610   95.958
# 2189    0.681       0.0912        0.1400    0.0831    0.637   92.027
# 1354    0.639       0.0688        0.0156    0.0545    0.675   99.002
# 10238   0.572       0.0951        0.0618    0.0495    0.695  100.999
# 181     0.558       0.0683        0.4820    0.0618    0.678   95.016
# 22355   0.663       0.0831        0.1650    0.0637    0.686  105.000
# 4616    0.666       0.0635        0.4880    0.1080    0.714   94.020
# 1254    0.676       0.0589        0.1380    0.0734    0.882  100.045
#
#        corr_score
# 29          29.00
# 11365       27.00
# 6117        27.00
# 6058        27.00
# 8934        27.00
# 25197       27.00
# 3609        26.80
# 1555        26.70
# 319         26.70
# 4867        26.50
# 3649        26.50
# 31          26.00
# 8721        26.00
# 2189        26.00
# 1354        26.00
# 10238       26.00
# 181         26.00
# 22355       26.00
# 4616        26.00
# 1254        25.95

# %%
#order - [tempo, energy, danceability, valence, liveness, speechiness, acousticness]
#points - 7, 6, 5, 4, 3, 2, 2 
# Above are the characterisitics to be correlated, and the corresponding max points that can be achieved.

#song_ind = song index, that is the song to be compared with other songs. ind, which changes with the for loop will correspond to the index of every other
#song that will be correlated with the our chosen song (song_ind). So `a` gets the tempo of our song, it compares it with the tempo of another song `b`
# `c` the absolute value of the difference is subjected to a series of conditional which determine the points it gets. The value is returned into a for loop
# The same basically applies for the rest of the characteristics to be compared.

# Tempo
def temp_corr(song_ind, ind):
    a = full.loc[song_ind, 'tempo']
    b = full.loc[ind, 'tempo']
    c = abs(a-b)
    if c <= 4:
        c = 7
    elif c <= 9:
        c = 5
    elif c <= 14:
        c = 3
    elif c <= 20:
        c = 1
    else:
        c = 0
    return c

# %%
# Energy
def energy_corr(song_ind, ind):
    a = full.loc[song_ind, 'energy']
    b = full.loc[ind, 'energy']
    c = abs(a-b)
    if c <= 0.07:
        c = 6    
    elif c <= 0.15:
        c = 4
    elif c <= 0.25:
        c = 2
    elif c <= 0.3:
        c = 2
    else:
        c = 0
    return c

# %%
# danceability
def dance_corr(song_ind, ind):
    a = full.loc[song_ind, 'danceability']
    b = full.loc[ind, 'danceability']
    c = abs(a-b)
    if c <= 0.09:
        c = 5    
    elif c <= 0.19:
        c = 3
    elif c <= 0.29:
        c = 1
    elif c <= 0.35:
        c = 0.5
    else:
        c = 0
    return c

# %%
# valence
def val_corr(song_ind, ind):
    a = full.loc[song_ind, 'valence']
    b = full.loc[ind, 'valence']
    c = abs(a-b)
    if c <= 0.09:
        c = 4    
    elif c <= 0.24:
        c = 2.75
    elif c <= 0.31:
        c = 1.85
    elif c <= 0.4:
        c = 0.7
    else:
        c = 0
    return c

# %%
# liveness
def liv_corr(song_ind, ind):
    a = full.loc[song_ind, 'liveness']
    b = full.loc[ind, 'liveness']
    c = abs(a-b)
    if c <= 0.04:
        c = 3   
    elif c <= 0.1:
        c = 2.3
    elif c <= 0.19:
        c = 1.85
    elif c <= 0.22:
        c = 0.7
    else:
        c = 0
    return c

# %%
# speechiness
def speech_corr(song_ind, ind):
    a = full.loc[song_ind, 'speechiness']
    b = full.loc[ind, 'speechiness']
    c = abs(a-b)
    if c <= 0.004:
        c = 2   
    elif c <= 0.01:
        c = 1.5
    elif c <= 0.019:
        c = 1.
    elif c <= 0.035:
        c = 0.7
    else:
        c = 0
    return c

# %%
# acousticness
def acoust_corr(song_ind, ind):
    a = full.loc[song_ind, 'acousticness']
    b = full.loc[ind, 'acousticness']
    c = abs(a-b)
    if c <= 0.004:
        c = 2   
    elif c <= 0.01:
        c = 1.5
    elif c <= 0.019:
        c = 1.
    elif c <= 0.035:
        c = 0.7
    else:
        c = 0
    return c

# %%
full.loc[[55]]

# %%
full['acousticness'].sample(100)
